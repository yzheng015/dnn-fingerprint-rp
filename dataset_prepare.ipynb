# %%
import torch
import sys
from PyTorch_CIFAR10_master.cifar10_models import *

# model = vgg11_bn(pretrained = True, device = device)

sys.path.append('/mnt/ssd1/zhengyue/Models/')

model_path = '/mnt/ssd1/zhengyue/Models'

# %% [markdown]
# # Prepare the target_models, positive_models, negative_models for the experiments.

# %%
#### Target Models
# torch.save(model_ft_ready.state_dict, save_model_path)
# torch.save(model_ft_ready, save_model_path)
### Target models
#cifar10_resnet20 = model_path + '/Target_models/cifar10-resnet20-30abc31d.pth'
cifar10_resnet20 = model_path + '/Target_models/cifar10_resnet20_checkpoint.th'
cifar10_vgg11 = model_path + '/Target_models/cifar10_vgg11_bn.pt'
cifar10_densenet161 = model_path + '/Target_models/cifar10_densenet161.pt'

cifar100_resnet20 = model_path + '/Target_models/cifar100_resnet20-8412cc70.pth'
cifar100_vgg11 = model_path + '/Target_models/cifar100_vgg11_model_0_99.pth'
cifar100_densenet161 = model_path + '/Target_models/cifar100_densenet161_model_0_99.pth'

imagenet10_resnet18 = model_path + '/Target_models/imagenet10_resnet18_model_0_29.pth'
imagenet10_vgg11 = model_path + '/Target_models/imagenet10_vgg11_model_0_49.pth'
imagenet10_densenet161 = model_path + '/Target_models/imagenet10_densenet161_model_0_99.pth'

##### Positive Suspect Models
## until the accuracy loss is larger than or equal to 3%
## fe: weights frozen in feature extraction part, while fully connected layer's weight can be modified
## fp: filter pruning, certain percentage of the filter's weights are setted to 0. 
## 0_14: use 15 epoches; 0_29: use 30 epoches. 
c10_pm_r20 = '/Positive_models/cifar10_resnet20_positive_suspect_saved_model/'
c10_pm_v11 = '/Positive_models/cifar10_vgg11_positive_suspect_saved_model/'
c10_pm_d161 = '/Positive_models/cifar10_densenet161_positive_suspect_saved_model/'

c100_pm_r20 = '/Positive_models/cifar100_resnet20_positive_suspect_saved_model/'
c100_pm_v11 = '/Positive_models/cifar100_vgg11_positive_suspect_saved_model/'
c100_pm_d161 = '/Positive_models/cifar100_densenet161_positive_suspect_saved_model/'

i10_pm_r18 = '/Positive_models/imagenet10_resnet18_positive_suspect_saved_model/'
i10_pm_v11 = '/Positive_models/imagenet10_vgg11_positive_suspect_saved_model/'
i10_pm_d161 = '/Positive_models/imagenet10_densenet161_positive_suspect_saved_model/'


# c10_r20_fe = model_path + c10_pm_r20 + 'fe1_model_0_29.pth'
# c10_r20_ft = model_path + c10_pm_r20 + 'ft_model_0_29.pth'
# c10_r20_fp1 = model_path + c10_pm_r20 + 'fp1_model_0_14.pth'
# c10_r20_fp2 = model_path + c10_pm_r20 + 'fp2_model_0_14.pth'
# c10_r20_fp3 = model_path + c10_pm_r20 + 'fp3_model_0_14.pth'
# c10_r20_wp1 = model_path + c10_pm_r20 + 'wp1_model_0_19.pth'
# c10_r20_wp2 = model_path + c10_pm_r20 + 'wp2_model_0_19.pth'
# c10_r20_wp3 = model_path + c10_pm_r20 + 'wp3_model_0_14.pth'
# c10_r20_wp4 = model_path + c10_pm_r20 + 'wp4_model_0_14.pth'
# c10_r20_wp5 = model_path + c10_pm_r20 + 'wp5_model_0_14.pth'
# c10_r20_wp6 = model_path + c10_pm_r20 + 'wp6_model_0_14.pth'

c10_r20_fe = model_path + c10_pm_r20 +'fe_resnet20_checkpoint_0_99.pth'
c10_r20_ft = model_path + c10_pm_r20 +'ft_resnet20_checkpoint_0_99.pth'
c10_r20_fp1 = model_path + c10_pm_r20 +'fp1_checkpoint_0_99.pth'
c10_r20_fp2 = model_path + c10_pm_r20 +'fp2_checkpoint_0_99.pth'
c10_r20_fp3 = model_path + c10_pm_r20 +'fp3_checkpoint_0_99.pth'
c10_r20_fp4 = model_path + c10_pm_r20 +'fp4_checkpoint_0_99.pth'
c10_r20_fp5 = model_path + c10_pm_r20 +'fp5_checkpoint_0_99.pth'
c10_r20_fp6 = model_path + c10_pm_r20 +'fp6_checkpoint_0_99.pth'
c10_r20_fp7 = model_path + c10_pm_r20 +'fp7_checkpoint_0_99.pth'
c10_r20_fp8 = model_path + c10_pm_r20 +'fp8_checkpoint_0_99.pth'
c10_r20_fp9 = model_path + c10_pm_r20 +'fp9_checkpoint_0_99.pth'
c10_r20_wp1 = model_path + c10_pm_r20 +'wp1_checkpoint_0_99.pth'
c10_r20_wp2 = model_path + c10_pm_r20 +'wp2_checkpoint_0_99.pth'
c10_r20_wp3 = model_path + c10_pm_r20 +'wp3_checkpoint_0_99.pth'
c10_r20_wp4 = model_path + c10_pm_r20 +'wp4_checkpoint_0_99.pth'
c10_r20_wp5 = model_path + c10_pm_r20 +'wp5_checkpoint_0_99.pth'
c10_r20_wp6 = model_path + c10_pm_r20 +'wp6_checkpoint_0_99.pth'
c10_r20_wp7 = model_path + c10_pm_r20 +'wp7_checkpoint_0_99.pth'
c10_r20_wp8 = model_path + c10_pm_r20 +'wp8_checkpoint_0_99.pth'
c10_r20_wp9 = model_path + c10_pm_r20 +'wp9_checkpoint_0_99.pth'


# c10_r20_wp7 = model_path + c10_pm_r20 + 'wp7_model_0_14.pth'


c10_v11_fe = model_path + c10_pm_v11 + 'fe_model_0_49.pth'
c10_v11_ft = model_path + c10_pm_v11 + 'ft_model_0_49.pth'
c10_v11_fp1 = model_path + c10_pm_v11 + 'fp1_model_0_49.pth'
c10_v11_fp2 = model_path + c10_pm_v11 + 'fp2_model_0_49.pth'
c10_v11_fp3 = model_path + c10_pm_v11 + 'fp3_model_0_49.pth'
c10_v11_fp4 = model_path + c10_pm_v11 + 'fp4_model_0_49.pth'
c10_v11_fp5 = model_path + c10_pm_v11 + 'fp5_model_0_49.pth'
c10_v11_fp6 = model_path + c10_pm_v11 + 'fp6_model_0_49.pth'
c10_v11_fp7 = model_path + c10_pm_v11 + 'fp7_model_0_49.pth'
c10_v11_fp8 = model_path + c10_pm_v11 + 'fp8_model_0_49.pth'
c10_v11_wp1 = model_path + c10_pm_v11 + 'wp1_model_0_49.pth'
c10_v11_wp2 = model_path + c10_pm_v11 + 'wp2_model_0_49.pth'
c10_v11_wp3 = model_path + c10_pm_v11 + 'wp3_model_0_49.pth'
c10_v11_wp4 = model_path + c10_pm_v11 + 'wp4_model_0_49.pth'
c10_v11_wp5 = model_path + c10_pm_v11 + 'wp5_model_0_49.pth'
c10_v11_wp6 = model_path + c10_pm_v11 + 'wp6_model_0_49.pth'
c10_v11_wp7 = model_path + c10_pm_v11 + 'wp7_model_0_49.pth'
c10_v11_wp8 = model_path + c10_pm_v11 + 'wp8_model_0_49.pth'
c10_v11_wp9 = model_path + c10_pm_v11 + 'wp9_model_0_49.pth'

c10_d161_fe = model_path + c10_pm_d161 + 'fe_model_0_49.pth'
c10_d161_ft = model_path + c10_pm_d161 + 'ft_model_0_49.pth'
c10_d161_fp1 = model_path + c10_pm_d161 + 'fp1_model_0_49.pth'
c10_d161_fp2 = model_path + c10_pm_d161 + 'fp2_model_0_49.pth'
c10_d161_fp3 = model_path + c10_pm_d161 + 'fp3_model_0_49.pth'
c10_d161_fp4 = model_path + c10_pm_d161 + 'fp4_model_0_49.pth'
c10_d161_fp5 = model_path + c10_pm_d161 + 'fp5_model_0_49.pth'
c10_d161_fp6 = model_path + c10_pm_d161 + 'fp6_model_0_49.pth'
c10_d161_fp7 = model_path + c10_pm_d161 + 'fp7_model_0_49.pth'
c10_d161_fp8 = model_path + c10_pm_d161 + 'fp8_model_0_49.pth'
c10_d161_fp9 = model_path + c10_pm_d161 + 'fp9_model_0_49.pth'
c10_d161_wp1 = model_path + c10_pm_d161 + 'wp1_model_0_49.pth'
c10_d161_wp2 = model_path + c10_pm_d161 + 'wp2_model_0_49.pth'
c10_d161_wp3 = model_path + c10_pm_d161 + 'wp3_model_0_49.pth'
c10_d161_wp4 = model_path + c10_pm_d161 + 'wp4_model_0_49.pth'
c10_d161_wp5 = model_path + c10_pm_d161 + 'wp5_model_0_49.pth'
c10_d161_wp6 = model_path + c10_pm_d161 + 'wp6_model_0_49.pth'
c10_d161_wp7 = model_path + c10_pm_d161 + 'wp7_model_0_49.pth'
c10_d161_wp8 = model_path + c10_pm_d161 + 'wp8_model_0_49.pth'
c10_d161_wp9 = model_path + c10_pm_d161 + 'wp9_model_0_49.pth'

c100_r20_fe = model_path + c100_pm_r20 + 'fe1_model_0_29.pth'
c100_r20_ft = model_path + c100_pm_r20 + 'ft_model_0_29.pth'
c100_r20_fp1 = model_path + c100_pm_r20 + 'fp1_model_0_19.pth'
c100_r20_fp2 = model_path + c100_pm_r20 + 'fp2_model_0_19.pth'
# c100_r20_fp3 = model_path + c100_pm_r20 + 'fp3_model_0_29.pth'
c100_r20_wp1 = model_path + c100_pm_r20 + 'wp1_model_0_29.pth'
c100_r20_wp2 = model_path + c100_pm_r20 + 'wp2_model_0_19.pth'
c100_r20_wp3 = model_path + c100_pm_r20 + 'wp3_model_0_19.pth'
c100_r20_wp4 = model_path + c100_pm_r20 + 'wp4_model_0_19.pth'
c100_r20_wp5 = model_path + c100_pm_r20 + 'wp5_model_0_19.pth'
c100_r20_wp6 = model_path + c100_pm_r20 + 'wp6_model_0_19.pth'

c100_v11_fe = model_path + c100_pm_v11 + 'fe_model_0_49.pth'
c100_v11_ft = model_path + c100_pm_v11 + 'ft_model_0_49.pth'
c100_v11_fp1 = model_path + c100_pm_v11 + 'fp1_model_0_49.pth'
c100_v11_fp2 = model_path + c100_pm_v11 + 'fp2_model_0_49.pth'
c100_v11_fp3 = model_path + c100_pm_v11 + 'fp3_model_0_49.pth'
c100_v11_fp4 = model_path + c100_pm_v11 + 'fp4_model_0_49.pth'
c100_v11_fp5 = model_path + c100_pm_v11 + 'fp5_model_0_49.pth'
c100_v11_fp6 = model_path + c100_pm_v11 + 'fp6_model_0_49.pth'
# c100_v11_fp7 = model_path + c100_pm_v11 + 'fp7_model_0_99.pth'
c100_v11_wp1 = model_path + c100_pm_v11 + 'wp1_model_0_49.pth'
c100_v11_wp2 = model_path + c100_pm_v11 + 'wp2_model_0_49.pth'
c100_v11_wp3 = model_path + c100_pm_v11 + 'wp3_model_0_49.pth'
c100_v11_wp4 = model_path + c100_pm_v11 + 'wp4_model_0_49.pth'
c100_v11_wp5 = model_path + c100_pm_v11 + 'wp5_model_0_49.pth'
c100_v11_wp6 = model_path + c100_pm_v11 + 'wp6_model_0_49.pth'
c100_v11_wp7 = model_path + c100_pm_v11 + 'wp7_model_0_49.pth'
c100_v11_wp8 = model_path + c100_pm_v11 + 'wp8_model_0_49.pth'
c100_v11_wp9 = model_path + c100_pm_v11 + 'wp9_model_0_49.pth'

c100_d161_fe = model_path + c100_pm_d161 + 'fe_model_0_49.pth'
c100_d161_ft = model_path + c100_pm_d161 + 'ft_model_0_49.pth'
c100_d161_fp1 = model_path + c100_pm_d161 + 'fp1_model_0_49.pth'
c100_d161_fp2 = model_path + c100_pm_d161 + 'fp2_model_0_49.pth'
c100_d161_fp3 = model_path + c100_pm_d161 + 'fp3_model_0_49.pth'
c100_d161_fp4 = model_path + c100_pm_d161 + 'fp4_model_0_49.pth'
c100_d161_fp5 = model_path + c100_pm_d161 + 'fp5_model_0_49.pth'
c100_d161_fp6 = model_path + c100_pm_d161 + 'fp6_model_0_49.pth'
c100_d161_fp7 = model_path + c100_pm_d161 + 'fp7_model_0_49.pth'
c100_d161_fp8 = model_path + c100_pm_d161 + 'fp8_model_0_49.pth'
# c100_d161_fp9 = model_path + c100_pm_d161 + 'fp9_model_0_99.pth'
c100_d161_wp1 = model_path + c100_pm_d161 + 'wp1_model_0_49.pth'
c100_d161_wp2 = model_path + c100_pm_d161 + 'wp2_model_0_49.pth'
c100_d161_wp3 = model_path + c100_pm_d161 + 'wp3_model_0_49.pth'
c100_d161_wp4 = model_path + c100_pm_d161 + 'wp4_model_0_49.pth'
c100_d161_wp5 = model_path + c100_pm_d161 + 'wp5_model_0_49.pth'
c100_d161_wp6 = model_path + c100_pm_d161 + 'wp6_model_0_49.pth'
c100_d161_wp7 = model_path + c100_pm_d161 + 'wp7_model_0_49.pth'
c100_d161_wp8 = model_path + c100_pm_d161 + 'wp8_model_0_49.pth'
c100_d161_wp9 = model_path + c100_pm_d161 + 'wp9_model_0_49.pth'

i10_r18_fe = model_path + i10_pm_r18 + 'resnet18fe1_model_0_29.pth'
i10_r18_ft = model_path + i10_pm_r18 + 'resnet18ft_model_0_29.pth'
# i10_r18_fp1 = model_path + i10_pm_r18 + 'resnet18fp1_model_0_49.pth'
i10_r18_wp1 = model_path + i10_pm_r18 + 'resnet18wp1_model_0_29.pth'
i10_r18_wp2 = model_path + i10_pm_r18 + 'resnet18wp2_model_0_29.pth'
i10_r18_wp3 = model_path + i10_pm_r18 + 'resnet18wp3_model_0_29.pth'
i10_r18_wp4 = model_path + i10_pm_r18 + 'resnet18wp4_model_0_29.pth'
i10_r18_wp5 = model_path + i10_pm_r18 + 'resnet18wp5_model_0_29.pth'

i10_v11_fe = model_path + i10_pm_v11 + 'vgg11fe_model_0_49.pth'
i10_v11_ft = model_path + i10_pm_v11 + 'vgg11ft_2_model_0_49.pth'
i10_v11_fp1 = model_path + i10_pm_v11 + 'vgg11fp1_2_model_0_49.pth'
i10_v11_fp2 = model_path + i10_pm_v11 + 'vgg11fp2_2_model_0_49.pth'
i10_v11_fp3 = model_path + i10_pm_v11 + 'vgg11fp3_2_model_0_49.pth'
i10_v11_fp4 = model_path + i10_pm_v11 + 'vgg11fp4_2_model_0_49.pth'
i10_v11_fp5 = model_path + i10_pm_v11 + 'vgg11fp5_2_model_0_49.pth'
i10_v11_fp6 = model_path + i10_pm_v11 + 'vgg11fp6_2_model_0_49.pth'
i10_v11_fp7 = model_path + i10_pm_v11 + 'vgg11fp7_2_model_0_49.pth'
i10_v11_fp8 = model_path + i10_pm_v11 + 'vgg11fp8_2_model_0_49.pth'
i10_v11_fp9 = model_path + i10_pm_v11 + 'vgg11fp9_2_model_0_49.pth'
i10_v11_wp1 = model_path + i10_pm_v11 + 'vgg11wp1_2_model_0_49.pth'
i10_v11_wp2 = model_path + i10_pm_v11 + 'vgg11wp2_2_model_0_49.pth'
i10_v11_wp3 = model_path + i10_pm_v11 + 'vgg11wp3_2_model_0_49.pth'
i10_v11_wp4 = model_path + i10_pm_v11 + 'vgg11wp4_2_model_0_49.pth'
i10_v11_wp5 = model_path + i10_pm_v11 + 'vgg11wp5_2_model_0_49.pth'
i10_v11_wp6 = model_path + i10_pm_v11 + 'vgg11wp6_2_model_0_49.pth'
i10_v11_wp7 = model_path + i10_pm_v11 + 'vgg11wp7_2_model_0_49.pth'
i10_v11_wp8 = model_path + i10_pm_v11 + 'vgg11wp8_2_model_0_49.pth'
i10_v11_wp9 = model_path + i10_pm_v11 + 'vgg11wp9_2_model_0_49.pth'


i10_d161_fe = model_path + i10_pm_d161 + 'densenet161fe_model_0_99.pth'
i10_d161_ft = model_path + i10_pm_d161 + 'densenet161ft_model_0_99.pth'
i10_d161_fp1 = model_path + i10_pm_d161 + 'densenet161fp1_model_0_99.pth'
i10_d161_fp2 = model_path + i10_pm_d161 + 'densenet161fp2_model_0_99.pth'
i10_d161_fp3 = model_path + i10_pm_d161 + 'densenet161fp3_model_0_99.pth'
i10_d161_fp4 = model_path + i10_pm_d161 + 'densenet161fp4_model_0_99.pth'
i10_d161_fp5 = model_path + i10_pm_d161 + 'densenet161fp5_model_0_99.pth'
i10_d161_fp6 = model_path + i10_pm_d161 + 'densenet161fp6_model_0_99.pth'
i10_d161_fp7 = model_path + i10_pm_d161 + 'densenet161fp7_model_0_99.pth'
i10_d161_fp8 = model_path + i10_pm_d161 + 'densenet161fp8_model_0_99.pth'
i10_d161_fp9 = model_path + i10_pm_d161 + 'densenet161fp9_model_0_99.pth'
i10_d161_wp1 = model_path + i10_pm_d161 + 'densenet161wp1_model_0_99.pth'
i10_d161_wp2 = model_path + i10_pm_d161 + 'densenet161wp2_model_0_99.pth'
i10_d161_wp3 = model_path + i10_pm_d161 + 'densenet161wp3_model_0_99.pth'
i10_d161_wp4 = model_path + i10_pm_d161 + 'densenet161wp4_model_0_99.pth'
i10_d161_wp5 = model_path + i10_pm_d161 + 'densenet161wp5_model_0_99.pth'
i10_d161_wp6 = model_path + i10_pm_d161 + 'densenet161wp6_model_0_99.pth'
i10_d161_wp7 = model_path + i10_pm_d161 + 'densenet161wp7_model_0_99.pth'
i10_d161_wp8 = model_path + i10_pm_d161 + 'densenet161wp8_model_0_99.pth'
i10_d161_wp9 = model_path + i10_pm_d161 + 'densenet161wp9_model_0_99.pth'


##### Negative suspect models
c10_nm_d121 = model_path + '/Negative_models/cifar10_models/densenet121.pt'
c10_nm_d161 = model_path + '/Negative_models/cifar10_models/densenet161.pt'
c10_nm_d169 = model_path + '/Negative_models/cifar10_models/densenet169.pt'
c10_nm_g = model_path + '/Negative_models/cifar10_models/googlenet.pt'
c10_nm_iv3 = model_path + '/Negative_models/cifar10_models/inception_v3.pt'
c10_nm_mv2 = model_path + '/Negative_models/cifar10_models/mobilenet_v2.pt'
c10_nm_r18 = model_path + '/Negative_models/cifar10_models/resnet18.pt'
c10_nm_r34 = model_path + '/Negative_models/cifar10_models/resnet34.pt'
c10_nm_r50 = model_path + '/Negative_models/cifar10_models/resnet50.pt'
c10_nm_v11 = model_path + '/Negative_models/cifar10_models/vgg11_bn.pt'
c10_nm_v13 = model_path + '/Negative_models/cifar10_models/vgg13_bn.pt'
c10_nm_v16 = model_path + '/Negative_models/cifar10_models/vgg16_bn.pt'
c10_nm_v19 = model_path + '/Negative_models/cifar10_models/vgg19_bn.pt'


c100_nm_d121 = model_path + '/Negative_models/cifar100_diff_saved_model/densenet121_model_0_49.pth'
c100_nm_d169 = model_path + '/Negative_models/cifar100_diff_saved_model/densenet169_model_0_99.pth'
c100_nm_g = model_path + '/Negative_models/cifar100_diff_saved_model/googlenet_model_0_29.pth'
c100_nm_iv3 = model_path + '/Negative_models/cifar100_diff_saved_model/inceptionv3_model_0_99.pth'
c100_nm_mv2 = model_path + '/Negative_models/cifar100_diff_saved_model/mobilenetv2_model_0_99.pth'
c100_nm_v13 = model_path + '/Negative_models/cifar100_diff_saved_model/vgg13_model_0_99.pth'
c100_nm_v16 = model_path + '/Negative_models/cifar100_diff_saved_model/vgg16_model_0_99.pth'
c100_nm_v19 = model_path + '/Negative_models/cifar100_diff_saved_model/vgg19_model_0_99.pth'


i10_nm_a = model_path + '/Negative_models/imagenet10_diff_saved_model/alexnet_model_0_99.pth'
i10_nm_d121 = model_path + '/Negative_models/imagenet10_diff_saved_model/densenet121_model_0_99.pth'
i10_nm_d169 = model_path + '/Negative_models/imagenet10_diff_saved_model/densenet169_model_0_99.pth'
i10_nm_r34 = model_path + '/Negative_models/imagenet10_diff_saved_model/resnet34_model_0_29.pth'
i10_nm_r50 = model_path + '/Negative_models/imagenet10_diff_saved_model/resnet50_model_0_99.pth'
i10_nm_s = model_path + '/Negative_models/imagenet10_diff_saved_model/squeezenet_model_0_99.pth'
i10_nm_v13 = model_path + '/Negative_models/imagenet10_diff_saved_model/vgg13_model_0_99.pth'
i10_nm_v16 = model_path + '/Negative_models/imagenet10_diff_saved_model/vgg16_model_0_99.pth'
i10_nm_v19 = model_path + '/Negative_models/imagenet10_diff_saved_model/vgg19_model_0_99.pth'

####

# print('done!')

# %%
target_c10 = [cifar10_resnet20, cifar10_vgg11, cifar10_densenet161]
target_c100 = [cifar100_resnet20, cifar100_vgg11, cifar100_densenet161]
target_i10 = [imagenet10_resnet18, imagenet10_vgg11, imagenet10_densenet161]

positive_c10_r20 = [c10_r20_fe,c10_r20_ft, c10_r20_fp1,c10_r20_fp2,c10_r20_fp3,c10_r20_fp4,c10_r20_fp5,c10_r20_fp6,c10_r20_fp7,c10_r20_fp8,c10_r20_fp9,
                   c10_r20_wp1,c10_r20_wp2,c10_r20_wp3,c10_r20_wp4,c10_r20_wp5,c10_r20_wp6,c10_r20_wp7,c10_r20_wp8,c10_r20_wp9]
#positive_c10_r20 = [c10_r20_fe, c10_r20_ft, c10_r20_fp1, c10_r20_fp2, c10_r20_fp3, c10_r20_wp1, c10_r20_wp2, c10_r20_wp3, c10_r20_wp4, c10_r20_wp5, c10_r20_wp6]
positive_c10_v11 = [c10_v11_fe, c10_v11_ft, c10_v11_fp1, c10_v11_fp2, c10_v11_fp3, c10_v11_fp4, c10_v11_fp5, c10_v11_fp6, c10_v11_fp7, c10_v11_fp8, c10_v11_wp1, c10_v11_wp2, c10_v11_wp3, c10_v11_wp4, c10_v11_wp5, c10_v11_wp6, c10_v11_wp7, c10_v11_wp8, c10_v11_wp9]
positive_c10_d161 = [c10_d161_fe, c10_d161_ft, c10_d161_fp1, c10_d161_fp2, c10_d161_fp3, c10_d161_fp4, c10_d161_fp5, c10_d161_fp6, c10_d161_fp7, c10_d161_fp8, c10_d161_fp9, c10_d161_wp1, c10_d161_wp2, c10_d161_wp3, c10_d161_wp4, c10_d161_wp5, c10_d161_wp6, c10_d161_wp7, c10_d161_wp8, c10_d161_wp9]
positive_c100_r20 = [c100_r20_fe, c100_r20_ft, c100_r20_fp1, c100_r20_fp2, c100_r20_wp1, c100_r20_wp2, c100_r20_wp3, c100_r20_wp4, c100_r20_wp5, c100_r20_wp6]
positive_c100_v11 = [c100_v11_fe, c100_v11_ft, c100_v11_fp1, c100_v11_fp2, c100_v11_fp3, c100_v11_fp4, c100_v11_fp5, c100_v11_fp6, c100_v11_wp1, c100_v11_wp2, c100_v11_wp3, c100_v11_wp4, c100_v11_wp5, c100_v11_wp6, c100_v11_wp7, c100_v11_wp8, c100_v11_wp9]
positive_c100_d161 = [c100_d161_fe, c100_d161_ft, c100_d161_fp1, c100_d161_fp2, c100_d161_fp3, c100_d161_fp4, c100_d161_fp5, c100_d161_fp6, c100_d161_fp7, c100_d161_fp8, c100_d161_wp1, c100_d161_wp2, c100_d161_wp3, c100_d161_wp4, c100_d161_wp5, c100_d161_wp6, c100_d161_wp7, c100_d161_wp8, c100_d161_wp9]
positive_i10_r18 = [i10_r18_fe, i10_r18_ft, i10_r18_wp1, i10_r18_wp2, i10_r18_wp3, i10_r18_wp4, i10_r18_wp5]
positive_i10_v11 = [i10_v11_fe, i10_v11_ft, i10_v11_fp1, i10_v11_fp2, i10_v11_fp3, i10_v11_fp4, i10_v11_fp5, i10_v11_fp6, i10_v11_fp7, i10_v11_fp8, i10_v11_fp9, i10_v11_wp1, i10_v11_wp2, i10_v11_wp3, i10_v11_wp4, i10_v11_wp5, i10_v11_wp6, i10_v11_wp7, i10_v11_wp8, i10_v11_wp9]
positive_i10_d161 = [i10_d161_fe, i10_d161_ft, i10_d161_fp1, i10_d161_fp2, i10_d161_fp3, i10_d161_fp4, i10_d161_fp5, i10_d161_fp6, i10_d161_fp7, i10_d161_fp8, i10_d161_fp9, i10_d161_wp1, i10_d161_wp2, i10_d161_wp3, i10_d161_wp4, i10_d161_wp5, i10_d161_wp6, i10_d161_wp7, i10_d161_wp8, i10_d161_wp9]

negative_c10 = [c10_nm_d121, c10_nm_d161, c10_nm_d169, c10_nm_g, c10_nm_iv3, c10_nm_mv2, c10_nm_v11, c10_nm_v13, c10_nm_v16, c10_nm_v19,c10_nm_r18, c10_nm_r34, c10_nm_r50]
negative_c100 = [c100_nm_d121, c100_nm_d169, c100_nm_g, c100_nm_iv3, c100_nm_mv2, c100_nm_v13, c100_nm_v16, c100_nm_v19]
negative_i10 = [i10_nm_d121, i10_nm_d169, i10_nm_v13, i10_nm_v16, i10_nm_v19, i10_nm_r34, i10_nm_r50, i10_nm_a, i10_nm_s]

# %% [raw]
# ### Test whether the models are loadable or not.
# model_list = negative_c100
# cnt = 0
# for model_item in model_list:
#     model = torch.load(model_item)
#     cnt += 1
# if cnt == len(model_list):
#     print('Successful!')

# %%
#### Write the model path information into a txt file. 

target = target_c10 + [''] + target_c100 + [''] + target_i10 + ['']
positive_c10 = positive_c10_r20 + [''] + positive_c10_v11 + [''] + positive_c10_d161 + ['']
positive_c100 = positive_c100_r20 + [''] + positive_c100_v11 + [''] + positive_c100_d161 + ['']
positive_i10 = positive_i10_r18 + [''] + positive_i10_v11 + [''] + positive_i10_d161 + ['']
negative = negative_c10 + [''] + negative_c100 + [''] + negative_i10
ALL = target + positive_c10 + positive_c100 + positive_i10 + negative

#### Write the model paths to a txt file
with open('allmodels.txt','w') as filehandle:
    filehandle.writelines('%s\n' % model for model in ALL)

# %% [markdown]
# # Cross Application Models

# %%
# c10_100_d161 means cifar100_densenet161 is fine tuned from c10_densenet161
c10_100_d161 = model_path + '/Target_models/cifar100_densenet161_model_0_99.pth' # = cifar100_vgg11
c10_100_v11 = model_path + '/Target_models/cifar100_vgg11_model_0_99.pth' # cifar100_densenet161

i10_r18 = model_path + '/Target_models/imagenet10_resnet18_model_0_29.pth'
i10_v11 = model_path + '/Target_models/imagenet10_vgg11_model_0_49.pth'
i10_d161 = model_path + '/Target_models/imagenet10_densenet161_model_0_99.pth'


CAM = '/Cross_Application_Models/'

c10_100_r20 = model_path + CAM + 'cifar10-100_ft_resnet20_model_0_99.pth'
c100_10_r20 = model_path + CAM + 'cifar100-10_ft_resnet20_model_0_99.pth'
c100_10_d161 = model_path + CAM + 'cifar100-10_ft_densenet161_model_0_99.pth'
c100_10_v11 = model_path + CAM + 'cifar100-10_ft_vgg11_model_0_99.pth'

CAM_models = [c10_100_r20, c10_100_v11, c10_100_d161, c100_10_r20, c100_10_v11, c100_10_d161, i10_r18, i10_v11, i10_d161]
#### Write the model paths to a txt file
with open('cross_application_models.txt','w') as filehandle:
    filehandle.writelines('%s\n' % model for model in CAM_models)
